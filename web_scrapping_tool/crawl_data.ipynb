# %%
import requests
from bs4 import BeautifulSoup

# %%
def check_page_not_found(soup):
    return soup.find({"class": "ah_404"}) is not None

# %%
def fetch_soup(url):
    try: 
        response = requests.get(url)
        response.raise_for_status()
        page_soup = BeautifulSoup(response.content, 'html.parser')
        
        if check_page_not_found(page_soup):
            print('Fail - Page Not Found 404')
            return None
    
        return page_soup
    except requests.exceptions.RequestException as e:
        print(f"Request failed: {e}")
        return None

# %%
def save_soup(soup, file_name):
    with open(file_name + '.html', 'w', encoding='utf-8') as f:
        f.write(str(soup))

# %%
def fetch_movie_title(soup):
    title = soup.find('h1', {"class": "heading_movie"}).text if soup.find('h1', {"class": "heading_movie"}) else 'N/A'
    return title

# %%
def fetch_movie_description(soup):
    description = soup.find('div', {"class": "desc ah-frame-bg"}).find('p').text if soup.find('div', {"class": "desc ah-frame-bg"}) and soup.find('div', {"class": "desc ah-frame-bg"}).find('p') else 'N/A'
    return description

# %%
def fetch_movie_genre(soup):
    genre = soup.find('div', {"class": "list_cate"}).text if soup.find('div', {"class": "list_cate"}) else 'N/A'
    genre_list = genre.splitlines()
    clean_genre_list = [g.strip() for g in genre_list if len(g.strip()) > 0][1:]
    return clean_genre_list

# %%
def fetch_movie_status(soup):
    status = soup.find('div', {"class": "status"})
    if status:
        status = status.find_all('div')[-1].text.strip()
    else:
        status = 'Undefined'
    return status

# %%
def fetch_movie_episodes(soup):     
    ep = soup.find('div', {'class':'list-item-episode scroll-bar'}).text if soup.find('div', {'class':'list-item-episode scroll-bar'}) else 'N/A'
    ep_list = ep.split()
    return len(ep_list)

# %%
def fetch_movie_release_year(soup):
    release_year = soup.find('div', {"class": "update_time"})
    if release_year:
        release_year = release_year.find_all('div')[-1].text.strip()
    else:
        release_year = 'N/A'
    return release_year

# %%
def fetch_movie_rating(soup):
    rating = soup.find('div', {"class": "score"}).text if soup.find('div', {"class": "score"}) else 'N/A'
    if rating != 'N/A':
        rating_parts = rating.split()
        if len(rating_parts) >= 4:
            return [rating_parts[1], rating_parts[3]]
        else:
            return 'Invalid rating format'
    else:
        return rating

# %%
def fetch_movie_information(soup):
    title = fetch_movie_title(soup)
    genre = fetch_movie_genre(soup)
    rating = fetch_movie_rating(soup)
    description = fetch_movie_description(soup)
    status = fetch_movie_status(soup)
    episodes = fetch_movie_episodes(soup)
    release_year = fetch_movie_release_year(soup)
    movie = {
        'title': title,
        'genre': genre,
        'rating': rating,
        'description': description,
        'status': status,
        'episodes': episodes,
        'release year': release_year
    }

    return movie

# %%
def fetch_pages(start_page = 1, end_page = 3):
    current_page = start_page
    film_list = []
    while current_page <= end_page:
        url = f"https://animehay.biz/the-loai/anime-{current_page}.html"
        print(f"Processing on page: ", url)
        
        soup = fetch_soup(url)
        if soup is None:
            break
            
        film_list.append(soup)
        current_page += 1
        print('\t----------\t----------\t---------\t----------\t----------\t---------')
        
    return film_list

# %%
all_soups = fetch_pages()
# Out:
# Processing on page:  https://animehay.biz/the-loai/anime-1.html
# 	----------	----------	---------	----------	----------	---------
# Processing on page:  https://animehay.biz/the-loai/anime-2.html
# 	----------	----------	---------	----------	----------	---------
# Processing on page:  https://animehay.biz/the-loai/anime-3.html
# 	----------	----------	---------	----------	----------	---------

# %%
def get_all_movies_links(soup):
    links = soup.find_all('a', href = True)
    specific_links = [link['href'] for link in links if "thong-tin-phim" in link['href']]
    return specific_links

# %%
all_links = []
for soup in all_soups:
    specific_links_soup = get_all_movies_links(soup)
    all_links.extend(specific_links_soup)

# %%
def fetch_all_movies(list_links, save = False):
    all_movies = {}
    for link in list_links:
        try:
            print(f"Processing link: {link}")
            movie_soup = fetch_soup(link)
            if not movie_soup:
                print(f"Failed to fetch data from {link}")
                continue
                
            information = fetch_movie_information(movie_soup)
            
            if save:
                save_soup(movie_soup, information['title'])
                
            all_movies[information['title']] = information
            
            print(f"Successfully processed: {information['title']}")
            print('----------\t---------\t----------')
        
        except Exception as ex:
            print(f"Error while processing link {link}: {ex}")
            
    return all_movies

# %%
all_movies = fetch_all_movies(all_links)
# Out:
# Processing link: https://animehay.biz/thong-tin-phim/makeine-too-many-losing-heroines-4117.html
# Successfully processed: Makeine: Too Many Losing Heroines!
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/shoshimin-how-to-become-ordinary-4106.html
# Successfully processed: Shoshimin: How to Become Ordinary
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/atri-my-dear-moments-4116.html
# Successfully processed: Atri: My Dear Moments
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/pokemon-horizons-the-series-3774.html
# Successfully processed: Pokémon Horizons: The Series
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/one-piece-34.html
# Successfully processed: One Piece
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/giji-harem-4094.html
# Successfully processed: Giji Harem
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/mob-kara-hajimaru-tansaku-eiyuutan-4102.html
# Successfully processed: Mob kara Hajimaru Tansaku Eiyuutan
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/synonyms-why-nobody-remembers-my-world-4115.html
# Successfully processed: Synonyms: Why Nobody Remembers My World?
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/tensui-no-sakuna-hime-4101.html
# Successfully processed: Tensui no Sakuna-hime
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/quality-assurance-in-another-world-4099.html
# Successfully processed: Quality Assurance in Another World
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/nier-automata-ver1-1a-3682.html
# Successfully processed: NieR:Automata Ver1.1a
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/boku-no-hero-academia-7th-season-4069.html
# Successfully processed: Boku no Hero Academia 7th Season
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/tensei-shitara-slime-datta-ken-3rd-season-4035.html
# Successfully processed: Tensei shitara Slime Datta Ken 3rd Season
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/ore-wa-subete-wo-parry-suru-gyaku-kanchigai-no-sekai-saikyou-wa-boukensha-ni-naritai-4095.html
# Successfully processed: Ore wa Subete wo [Parry] Suru: Gyaku Kanchigai no Sekai Saikyou wa Boukensha ni Naritai
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/tasogare-outfocus-4097.html
# Successfully processed: Tasogare Outfocus
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/hazure-waku-no-joutai-ijou-skill-de-saikyou-ni-natta-ore-ga-subete-wo-juurin-suru-made-4096.html
# Successfully processed: Hazure Waku no [Joutai Ijou Skill] de Saikyou ni Natta Ore ga Subete wo Juurin Suru made
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/gimai-seikatsu-4093.html
# Successfully processed: Gimai Seikatsu
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/tokidoki-bosotto-russia-go-de-dereru-tonari-no-alya-san-4091.html
# Successfully processed: Tokidoki Bosotto Russia-go de Dereru Tonari no Alya-san
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/doraemon-movie-43-nobita-va-ban-giao-huong-dia-cau-4134.html
# Successfully processed: Doraemon Movie 43 Nobita Và Bản Giao Hưởng Địa Cầu
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/senpai-wa-otokonoko-4121.html
# Successfully processed: Senpai wa Otokonoko
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/isekai-shikkaku-4119.html
# Successfully processed: Isekai Shikkaku
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/katsute-mahou-shoujo-to-aku-wa-tekitai-shiteita-4112.html
# Successfully processed: Katsute Mahou Shoujo to Aku wa Tekitai Shiteita
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/henjin-no-salad-bowl-4050.html
# Successfully processed: Henjin no Salad Bowl
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/maou-gun-saikyou-no-majutsushi-wa-ningen-datta-4085.html
# Successfully processed: Maou Gun Saikyou No Majutsushi Wa Ningen Datta
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/mission-yozakura-family-4043.html
# Successfully processed: Mission: Yozakura Family
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/shy-3892.html
# Successfully processed: Shy
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/midnight-punch-4110.html
# Successfully processed: Midnight Punch
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/madougushi-dahliya-wa-utsumukanai-4130.html
# Successfully processed: Madougushi Dahliya wa Utsumukanai
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/the-fable-4054.html
# Successfully processed: The Fable
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/ramen-akaneko-4127.html
# Successfully processed: Ramen Akaneko
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/pokemon-horizons-the-series-3774.html
# Successfully processed: Pokémon Horizons: The Series
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/one-piece-34.html
# Successfully processed: One Piece
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/mob-kara-hajimaru-tansaku-eiyuutan-4102.html
# Successfully processed: Mob kara Hajimaru Tansaku Eiyuutan
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/synonyms-why-nobody-remembers-my-world-4115.html
# Successfully processed: Synonyms: Why Nobody Remembers My World?
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/tensui-no-sakuna-hime-4101.html
# Successfully processed: Tensui no Sakuna-hime
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/quality-assurance-in-another-world-4099.html
# Successfully processed: Quality Assurance in Another World
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/nier-automata-ver1-1a-3682.html
# Successfully processed: NieR:Automata Ver1.1a
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/boku-no-hero-academia-7th-season-4069.html
# Successfully processed: Boku no Hero Academia 7th Season
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/tensei-shitara-slime-datta-ken-3rd-season-4035.html
# Successfully processed: Tensei shitara Slime Datta Ken 3rd Season
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/ore-wa-subete-wo-parry-suru-gyaku-kanchigai-no-sekai-saikyou-wa-boukensha-ni-naritai-4095.html
# Successfully processed: Ore wa Subete wo [Parry] Suru: Gyaku Kanchigai no Sekai Saikyou wa Boukensha ni Naritai
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/hazure-waku-no-joutai-ijou-skill-de-saikyou-ni-natta-ore-ga-subete-wo-juurin-suru-made-4096.html
# Successfully processed: Hazure Waku no [Joutai Ijou Skill] de Saikyou ni Natta Ore ga Subete wo Juurin Suru made
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/isekai-shikkaku-4119.html
# Successfully processed: Isekai Shikkaku
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/maou-gun-saikyou-no-majutsushi-wa-ningen-datta-4085.html
# Successfully processed: Maou Gun Saikyou No Majutsushi Wa Ningen Datta
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/mission-yozakura-family-4043.html
# Successfully processed: Mission: Yozakura Family
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/shy-3892.html
# Successfully processed: Shy
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/shinmai-ossan-bouken-sha-saikyou-party-ni-shinu-hodo-kitaerarete-muteki-ni-naru-4089.html
# Successfully processed: Shinmai Ossan Bouken-sha, Saikyou Party ni Shinu Hodo Kitaerarete Muteki ni Naru
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/the-elusive-samurai-4113.html
# Successfully processed: The Elusive Samurai
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/isekai-yururi-kikou-kosodate-shinagara-boukensha-shimasu-4109.html
# Successfully processed: Isekai Yururi Kikou: Kosodate Shinagara Boukensha Shimasu
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/wistoria-wand-and-sword-4107.html
# Successfully processed: Wistoria: Wand and Sword
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/tower-of-god-season-2-4104.html
# Successfully processed: Tower of God Season 2
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/fairy-tail-100-years-quest-4103.html
# Successfully processed: Fairy Tail: 100 Years Quest
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/tasuuketsu-4123.html
# Successfully processed: Tasuuketsu
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/sengoku-youko-3994.html
# Successfully processed: Sengoku Youko
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/toan-chuc-phap-su-4132.html
# Successfully processed: Toàn Chức Pháp Sư
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/kengan-ashura-3nd-season-3885.html
# Successfully processed: Kengan Ashura 3nd Season
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/kim-ngo-ve-4075.html
# Successfully processed: Kim Ngô Vệ
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/suicide-squad-isekai-4087.html
# Successfully processed: Suicide Squad ISEKAI
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/spy-family-code-white-4126.html
# Successfully processed: SPY×FAMILY CODE: White
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/bye-bye-earth-4124.html
# Successfully processed: Bye Bye, Earth
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/kimi-to-boku-no-saigo-no-senjou-aruiwa-sekai-ga-hajimaru-seisen-season-ii-4111.html
# Successfully processed: Kimi to Boku no Saigo no Senjou, Aruiwa Sekai ga Hajimaru Seisen Season II
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/pokemon-horizons-the-series-3774.html
# Successfully processed: Pokémon Horizons: The Series
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/one-piece-34.html
# Successfully processed: One Piece
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/tensei-shitara-slime-datta-ken-3rd-season-4035.html
# Successfully processed: Tensei shitara Slime Datta Ken 3rd Season
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/tokidoki-bosotto-russia-go-de-dereru-tonari-no-alya-san-4091.html
# Successfully processed: Tokidoki Bosotto Russia-go de Dereru Tonari no Alya-san
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/doraemon-movie-43-nobita-va-ban-giao-huong-dia-cau-4134.html
# Successfully processed: Doraemon Movie 43 Nobita Và Bản Giao Hưởng Địa Cầu
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/isekai-shikkaku-4119.html
# Successfully processed: Isekai Shikkaku
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/henjin-no-salad-bowl-4050.html
# Successfully processed: Henjin no Salad Bowl
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/mission-yozakura-family-4043.html
# Successfully processed: Mission: Yozakura Family
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/shinmai-ossan-bouken-sha-saikyou-party-ni-shinu-hodo-kitaerarete-muteki-ni-naru-4089.html
# Successfully processed: Shinmai Ossan Bouken-sha, Saikyou Party ni Shinu Hodo Kitaerarete Muteki ni Naru
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/midnight-punch-4110.html
# Successfully processed: Midnight Punch
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/the-fable-4054.html
# Successfully processed: The Fable
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/ramen-akaneko-4127.html
# Successfully processed: Ramen Akaneko
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/monogatari-series-off-monster-season-4129.html
# Successfully processed: Monogatari Series: Off & Monster Season
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/koi-wa-futago-de-warikirenai-4120.html
# Successfully processed: Koi wa Futago de Warikirenai
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/kinnikuman-perfect-origin-arc-4114.html
# Successfully processed: Kinnikuman Perfect Origin Arc
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/isekai-yururi-kikou-kosodate-shinagara-boukensha-shimasu-4109.html
# Successfully processed: Isekai Yururi Kikou: Kosodate Shinagara Boukensha Shimasu
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/vtuber-legend-how-i-went-viral-after-forgetting-to-turn-off-my-stream-4108.html
# Successfully processed: VTuber Legend: How I Went Viral after Forgetting to Turn Off My Stream
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/shikanoko-nokonoko-koshitantan-4092.html
# Successfully processed: Shikanoko Nokonoko Koshitantan
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/2-5-jigen-no-ririsa-4100.html
# Successfully processed: 2.5-jigen no Ririsa
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/spy-family-code-white-4126.html
# Successfully processed: SPY×FAMILY CODE: White
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/shinigami-bocchan-to-kuro-maid-3rd-season-4048.html
# Successfully processed: Shinigami Bocchan to Kuro Maid 3rd Season
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/lv2-kara-cheat-datta-motoyuusha-kouho-no-mattari-isekai-life-4051.html
# Successfully processed: Lv2 kara Cheat datta Motoyuusha Kouho no Mattari Isekai Life
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/shuumatsu-train-doko-e-iku-4026.html
# Successfully processed: Shuumatsu Train Doko E Iku
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/tsuki-ga-michibiku-isekai-douchuu-2nd-season-3989.html
# Successfully processed: Tsuki ga Michibiku Isekai Douchuu 2nd Season
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/yoru-no-kurage-wa-oyogenai-4039.html
# Successfully processed: Yoru no Kurage wa Oyogenai
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/maou-no-ore-ga-dorei-elf-wo-yome-ni-shitanda-ga-dou-medereba-ii-4031.html
# Successfully processed: Maou No Ore Ga Dorei Elf Wo Yome Ni Shitanda Ga, Dou Medereba Ii?
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/astro-note-4036.html
# Successfully processed: Astro Note
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/kono-subarashii-sekai-ni-shukufuku-wo-3-4023.html
# Successfully processed: Kono Subarashii Sekai ni Shukufuku wo! 3
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/tensei-shitara-dainana-ouji-datta-node-kimama-ni-majutsu-wo-kiwamemasu-4025.html
# Successfully processed: Tensei shitara Dainana Ouji Datta node, Kimama ni Majutsu wo Kiwamemasu
# ----------	---------	----------
# Processing link: https://animehay.biz/thong-tin-phim/jiisan-baasan-wakagaeru-4047.html
# Successfully processed: Jiisan Baasan Wakagaeru
# ----------	---------	----------

# %%
import json
def save_json(data, filename):
    with open(filename + '.json', 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

# %%
save_json(all_movies, 'data_movies')

# %%
def print_json(filename):
    with open(filename + '.json', 'r', encoding='utf-8') as f:
        data = json.load(f)
        print(json.dumps(data, ensure_ascii=False, indent=4))

print_json('data_movies')
# Out:
# {
#     "Makeine: Too Many Losing Heroines!": {
#         "title": "Makeine: Too Many Losing Heroines!",
#         "genre": [
#             "Anime",
#             "Tình cảm",
#             "Học đường",
#             "Đời thường"
#         ],
#         "rating": [
#             "8.7",
#             "99"
#         ]
#     },
#     "Shoshimin: How to Become Ordinary": {
#         "title": "Shoshimin: How to Become Ordinary",
#         "genre": [
#             "Anime",
#             "Học đường",
#             "Đời thường"
#         ],
#         "rating": [
#             "7.3",
#             "47"
#         ]
#     },
#     "Atri: My Dear Moments": {
#         "title": "Atri: My Dear Moments",
#         "genre": [
#             "Anime",
#             "Tình cảm",
#             "Drama"
#         ],
#         "rating": [
#             "7.5",
#             "41"
#         ]
#     },
#     "Pokémon Horizons: The Series": {
#         "title": "Pokémon Horizons: The Series",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Hài hước",
#             "Phiêu lưu"
#         ],
#         "rating": [
#             "5.3",
#             "201"
#         ]
#     },
#     "One Piece": {
#         "title": "One Piece",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Hài hước",
#             "Phiêu lưu",
#             "Shounen",
#             "Drama"
#         ],
#         "rating": [
#             "9.0",
#             "16359"
#         ]
#     },
#     "Giji Harem": {
#         "title": "Giji Harem",
#         "genre": [
#             "Anime",
#             "Học đường",
#             "Đời thường",
#             "Shounen"
#         ],
#         "rating": [
#             "8.7",
#             "107"
#         ]
#     },
#     "Mob kara Hajimaru Tansaku Eiyuutan": {
#         "title": "Mob kara Hajimaru Tansaku Eiyuutan",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Harem",
#             "Siêu nhiên",
#             "Phiêu lưu"
#         ],
#         "rating": [
#             "7.2",
#             "107"
#         ]
#     },
#     "Synonyms: Why Nobody Remembers My World?": {
#         "title": "Synonyms: Why Nobody Remembers My World?",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Siêu nhiên",
#             "Phiêu lưu"
#         ],
#         "rating": [
#             "7.5",
#             "82"
#         ]
#     },
#     "Tensui no Sakuna-hime": {
#         "title": "Tensui no Sakuna-hime",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Siêu nhiên"
#         ],
#         "rating": [
#             "5.1",
#             "26"
#         ]
#     },
#     "Quality Assurance in Another World": {
#         "title": "Quality Assurance in Another World",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Siêu nhiên",
#             "Phiêu lưu",
#             "Viễn tưởng"
#         ],
#         "rating": [
#             "6.6",
#             "48"
#         ]
#     },
#     "NieR:Automata Ver1.1a": {
#         "title": "NieR:Automata Ver1.1a",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Giả tưởng",
#             "Viễn tưởng"
#         ],
#         "rating": [
#             "8.3",
#             "192"
#         ]
#     },
#     "Boku no Hero Academia 7th Season": {
#         "title": "Boku no Hero Academia 7th Season",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Học đường",
#             "Siêu năng lực",
#             "Shounen"
#         ],
#         "rating": [
#             "8.9",
#             "175"
#         ]
#     },
#     "Tensei shitara Slime Datta Ken 3rd Season": {
#         "title": "Tensei shitara Slime Datta Ken 3rd Season",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Hài hước",
#             "Giả tưởng",
#             "Shounen",
#             "Phiêu lưu"
#         ],
#         "rating": [
#             "8.9",
#             "455"
#         ]
#     },
#     "Ore wa Subete wo [Parry] Suru: Gyaku Kanchigai no Sekai Saikyou wa Boukensha ni Naritai": {
#         "title": "Ore wa Subete wo [Parry] Suru: Gyaku Kanchigai no Sekai Saikyou wa Boukensha ni Naritai",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Siêu nhiên",
#             "Phiêu lưu"
#         ],
#         "rating": [
#             "8.2",
#             "185"
#         ]
#     },
#     "Tasogare Outfocus": {
#         "title": "Tasogare Outfocus",
#         "genre": [
#             "Anime",
#             "Học đường",
#             "Đời thường"
#         ],
#         "rating": [
#             "3.2",
#             "116"
#         ]
#     },
#     "Hazure Waku no [Joutai Ijou Skill] de Saikyou ni Natta Ore ga Subete wo Juurin Suru made": {
#         "title": "Hazure Waku no [Joutai Ijou Skill] de Saikyou ni Natta Ore ga Subete wo Juurin Suru made",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Drama",
#             "Siêu nhiên",
#             "Phiêu lưu"
#         ],
#         "rating": [
#             "8.2",
#             "203"
#         ]
#     },
#     "Gimai Seikatsu": {
#         "title": "Gimai Seikatsu",
#         "genre": [
#             "Anime",
#             "Tình cảm"
#         ],
#         "rating": [
#             "8.9",
#             "153"
#         ]
#     },
#     "Tokidoki Bosotto Russia-go de Dereru Tonari no Alya-san": {
#         "title": "Tokidoki Bosotto Russia-go de Dereru Tonari no Alya-san",
#         "genre": [
#             "Anime",
#             "Hài hước",
#             "Tình cảm",
#             "Học đường"
#         ],
#         "rating": [
#             "9.2",
#             "350"
#         ]
#     },
#     "Doraemon Movie 43 Nobita Và Bản Giao Hưởng Địa Cầu": {
#         "title": "Doraemon Movie 43 Nobita Và Bản Giao Hưởng Địa Cầu",
#         "genre": [
#             "Anime",
#             "Hài hước",
#             "Siêu nhiên",
#             "Phiêu lưu"
#         ],
#         "rating": [
#             "8.8",
#             "17"
#         ]
#     },
#     "Senpai wa Otokonoko": {
#         "title": "Senpai wa Otokonoko",
#         "genre": [
#             "Anime",
#             "Tình cảm",
#             "Học đường"
#         ],
#         "rating": [
#             "5.6",
#             "23"
#         ]
#     },
#     "Isekai Shikkaku": {
#         "title": "Isekai Shikkaku",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Hài hước",
#             "Phiêu lưu"
#         ],
#         "rating": [
#             "8.2",
#             "107"
#         ]
#     },
#     "Katsute Mahou Shoujo to Aku wa Tekitai Shiteita": {
#         "title": "Katsute Mahou Shoujo to Aku wa Tekitai Shiteita",
#         "genre": [
#             "Anime",
#             "Tình cảm",
#             "Siêu nhiên"
#         ],
#         "rating": [
#             "8.2",
#             "60"
#         ]
#     },
#     "Henjin no Salad Bowl": {
#         "title": "Henjin no Salad Bowl",
#         "genre": [
#             "Anime",
#             "Hài hước",
#             "Giả tưởng"
#         ],
#         "rating": [
#             "7.6",
#             "49"
#         ]
#     },
#     "Maou Gun Saikyou No Majutsushi Wa Ningen Datta": {
#         "title": "Maou Gun Saikyou No Majutsushi Wa Ningen Datta",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Siêu nhiên",
#             "Xuyên không"
#         ],
#         "rating": [
#             "7.1",
#             "116"
#         ]
#     },
#     "Mission: Yozakura Family": {
#         "title": "Mission: Yozakura Family",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Hài hước",
#             "Tình cảm",
#             "Siêu năng lực"
#         ],
#         "rating": [
#             "8.4",
#             "146"
#         ]
#     },
#     "Shy": {
#         "title": "Shy",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Siêu năng lực",
#             "Drama"
#         ],
#         "rating": [
#             "5.2",
#             "69"
#         ]
#     },
#     "Midnight Punch": {
#         "title": "Midnight Punch",
#         "genre": [
#             "Anime",
#             "Hài hước",
#             "Đời thường"
#         ],
#         "rating": [
#             "5.7",
#             "38"
#         ]
#     },
#     "Madougushi Dahliya wa Utsumukanai": {
#         "title": "Madougushi Dahliya wa Utsumukanai",
#         "genre": [
#             "Anime",
#             "Giả tưởng",
#             "Đời thường",
#             "Dị giới"
#         ],
#         "rating": [
#             "6.6",
#             "25"
#         ]
#     },
#     "The Fable": {
#         "title": "The Fable",
#         "genre": [
#             "Anime",
#             "Hài hước",
#             "Seinen"
#         ],
#         "rating": [
#             "6.8",
#             "35"
#         ]
#     },
#     "Ramen Akaneko": {
#         "title": "Ramen Akaneko",
#         "genre": [
#             "Anime",
#             "Hài hước",
#             "Shounen"
#         ],
#         "rating": [
#             "6.7",
#             "11"
#         ]
#     },
#     "Shinmai Ossan Bouken-sha, Saikyou Party ni Shinu Hodo Kitaerarete Muteki ni Naru": {
#         "title": "Shinmai Ossan Bouken-sha, Saikyou Party ni Shinu Hodo Kitaerarete Muteki ni Naru",
#         "genre": [
#             "Hành động",
#             "Hài hước",
#             "Phiêu lưu"
#         ],
#         "rating": [
#             "7.5",
#             "136"
#         ]
#     },
#     "The Elusive Samurai": {
#         "title": "The Elusive Samurai",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Lịch sử",
#             "Drama",
#             "Phiêu lưu",
#             "Samurai"
#         ],
#         "rating": [
#             "7.9",
#             "72"
#         ]
#     },
#     "Isekai Yururi Kikou: Kosodate Shinagara Boukensha Shimasu": {
#         "title": "Isekai Yururi Kikou: Kosodate Shinagara Boukensha Shimasu",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Hài hước",
#             "Phiêu lưu",
#             "Dị giới"
#         ],
#         "rating": [
#             "7.3",
#             "96"
#         ]
#     },
#     "Wistoria: Wand and Sword": {
#         "title": "Wistoria: Wand and Sword",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Học đường",
#             "Siêu nhiên",
#             "Phiêu lưu"
#         ],
#         "rating": [
#             "8.6",
#             "231"
#         ]
#     },
#     "Tower of God Season 2": {
#         "title": "Tower of God Season 2",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Bí ẩn",
#             "Giả tưởng",
#             "Drama",
#             "Phiêu lưu"
#         ],
#         "rating": [
#             "8.9",
#             "140"
#         ]
#     },
#     "Fairy Tail: 100 Years Quest": {
#         "title": "Fairy Tail: 100 Years Quest",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Giả tưởng",
#             "Phiêu lưu"
#         ],
#         "rating": [
#             "9.4",
#             "214"
#         ]
#     },
#     "Tasuuketsu": {
#         "title": "Tasuuketsu",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Drama"
#         ],
#         "rating": [
#             "3.3",
#             "30"
#         ]
#     },
#     "Sengoku Youko": {
#         "title": "Sengoku Youko",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Giả tưởng",
#             "Shounen",
#             "Drama",
#             "Siêu nhiên",
#             "Phiêu lưu"
#         ],
#         "rating": [
#             "7.1",
#             "82"
#         ]
#     },
#     "Toàn Chức Pháp Sư": {
#         "title": "Toàn Chức Pháp Sư",
#         "genre": [
#             "Hành động",
#             "Siêu năng lực",
#             "CN Animation"
#         ],
#         "rating": [
#             "9.0",
#             "27"
#         ]
#     },
#     "Kengan Ashura 3nd Season": {
#         "title": "Kengan Ashura 3nd Season",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Võ thuật"
#         ],
#         "rating": [
#             "8.3",
#             "52"
#         ]
#     },
#     "Kim Ngô Vệ": {
#         "title": "Kim Ngô Vệ",
#         "genre": [
#             "Hành động",
#             "Thám tử",
#             "CN Animation",
#             "Huyền ảo"
#         ],
#         "rating": [
#             "6.1",
#             "46"
#         ]
#     },
#     "Suicide Squad ISEKAI": {
#         "title": "Suicide Squad ISEKAI",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Xuyên không"
#         ],
#         "rating": [
#             "8.1",
#             "79"
#         ]
#     },
#     "SPY×FAMILY CODE: White": {
#         "title": "SPY×FAMILY CODE: White",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Hài hước",
#             "Đời thường"
#         ],
#         "rating": [
#             "9.5",
#             "53"
#         ]
#     },
#     "Bye Bye, Earth": {
#         "title": "Bye Bye, Earth",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Giả tưởng",
#             "Phiêu lưu"
#         ],
#         "rating": [
#             "6.3",
#             "14"
#         ]
#     },
#     "Kimi to Boku no Saigo no Senjou, Aruiwa Sekai ga Hajimaru Seisen Season II": {
#         "title": "Kimi to Boku no Saigo no Senjou, Aruiwa Sekai ga Hajimaru Seisen Season II",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Tình cảm",
#             "Giả tưởng",
#             "Quân đội"
#         ],
#         "rating": [
#             "7.3",
#             "53"
#         ]
#     },
#     "Monogatari Series: Off & Monster Season": {
#         "title": "Monogatari Series: Off & Monster Season",
#         "genre": [
#             "Anime",
#             "Hài hước",
#             "Bí ẩn",
#             "Siêu nhiên",
#             "Ma cà rồng"
#         ],
#         "rating": [
#             "7.9",
#             "27"
#         ]
#     },
#     "Koi wa Futago de Warikirenai": {
#         "title": "Koi wa Futago de Warikirenai",
#         "genre": [
#             "Anime",
#             "Hài hước",
#             "Tình cảm"
#         ],
#         "rating": [
#             "6.3",
#             "39"
#         ]
#     },
#     "Kinnikuman Perfect Origin Arc": {
#         "title": "Kinnikuman Perfect Origin Arc",
#         "genre": [
#             "Anime",
#             "Hài hước",
#             "Thể thao"
#         ],
#         "rating": [
#             "2.4",
#             "25"
#         ]
#     },
#     "VTuber Legend: How I Went Viral after Forgetting to Turn Off My Stream": {
#         "title": "VTuber Legend: How I Went Viral after Forgetting to Turn Off My Stream",
#         "genre": [
#             "Anime",
#             "Hài hước",
#             "Tình cảm",
#             "Giả tưởng",
#             "Đời thường"
#         ],
#         "rating": [
#             "6.5",
#             "47"
#         ]
#     },
#     "Shikanoko Nokonoko Koshitantan": {
#         "title": "Shikanoko Nokonoko Koshitantan",
#         "genre": [
#             "Anime",
#             "Hài hước",
#             "Học đường"
#         ],
#         "rating": [
#             "8.4",
#             "120"
#         ]
#     },
#     "2.5-jigen no Ririsa": {
#         "title": "2.5-jigen no Ririsa",
#         "genre": [
#             "Anime",
#             "Hài hước",
#             "Harem",
#             "Học đường",
#             "Đời thường",
#             "Ecchi"
#         ],
#         "rating": [
#             "8.4",
#             "91"
#         ]
#     },
#     "Shinigami Bocchan to Kuro Maid 3rd Season": {
#         "title": "Shinigami Bocchan to Kuro Maid 3rd Season",
#         "genre": [
#             "Anime",
#             "Hài hước",
#             "Tình cảm",
#             "Siêu nhiên"
#         ],
#         "rating": [
#             "8.5",
#             "80"
#         ]
#     },
#     "Lv2 kara Cheat datta Motoyuusha Kouho no Mattari Isekai Life": {
#         "title": "Lv2 kara Cheat datta Motoyuusha Kouho no Mattari Isekai Life",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Hài hước",
#             "Tình cảm",
#             "Giả tưởng",
#             "Phiêu lưu"
#         ],
#         "rating": [
#             "8.2",
#             "227"
#         ]
#     },
#     "Shuumatsu Train Doko E Iku": {
#         "title": "Shuumatsu Train Doko E Iku",
#         "genre": [
#             "Anime",
#             "Hài hước",
#             "Đời thường",
#             "Phiêu lưu",
#             "Viễn tưởng"
#         ],
#         "rating": [
#             "6.7",
#             "64"
#         ]
#     },
#     "Tsuki ga Michibiku Isekai Douchuu 2nd Season": {
#         "title": "Tsuki ga Michibiku Isekai Douchuu 2nd Season",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Hài hước",
#             "Giả tưởng",
#             "Phiêu lưu",
#             "Xuyên không"
#         ],
#         "rating": [
#             "9.0",
#             "555"
#         ]
#     },
#     "Yoru no Kurage wa Oyogenai": {
#         "title": "Yoru no Kurage wa Oyogenai",
#         "genre": [
#             "Anime",
#             "Hài hước",
#             "Đời thường"
#         ],
#         "rating": [
#             "7.5",
#             "64"
#         ]
#     },
#     "Maou No Ore Ga Dorei Elf Wo Yome Ni Shitanda Ga, Dou Medereba Ii?": {
#         "title": "Maou No Ore Ga Dorei Elf Wo Yome Ni Shitanda Ga, Dou Medereba Ii?",
#         "genre": [
#             "Anime",
#             "Hành động",
#             "Hài hước",
#             "Tình cảm"
#         ],
#         "rating": [
#             "8.7",
#             "252"
#         ]
#     },
#     "Astro Note": {
#         "title": "Astro Note",
#         "genre": [
#             "Anime",
#             "Hài hước",
#             "Tình cảm",
#             "Siêu nhiên"
#         ],
#         "rating": [
#             "4.9",
#             "43"
#         ]
#     },
#     "Kono Subarashii Sekai ni Shukufuku wo! 3": {
#         "title": "Kono Subarashii Sekai ni Shukufuku wo! 3",
#         "genre": [
#             "Anime",
#             "Hài hước",
#             "Giả tưởng",
#             "Phiêu lưu",
#             "Dị giới"
#         ],
#         "rating": [
#             "9.5",
#             "282"
#         ]
#     },
#     "Tensei shitara Dainana Ouji Datta node, Kimama ni Majutsu wo Kiwamemasu": {
#         "title": "Tensei shitara Dainana Ouji Datta node, Kimama ni Majutsu wo Kiwamemasu",
#         "genre": [
#             "Anime",
#             "Hài hước",
#             "Phiêu lưu",
#             "Xuyên không"
#         ],
#         "rating": [
#             "7.1",
#             "408"
#         ]
#     },
#     "Jiisan Baasan Wakagaeru": {
#         "title": "Jiisan Baasan Wakagaeru",
#         "genre": [
#             "Anime",
#             "Hài hước",
#             "Tình cảm",
#             "Đời thường",
#             "Siêu nhiên"
#         ],
#         "rating": [
#             "9.1",
#             "203"
#         ]
#     }
# }

# %%
import pandas as pd


def json_to_csv(json_filename, csv_filename):
    with open(json_filename + '.json', 'r', encoding='utf-8') as f:
        data = json.load(f)
    

    df = pd.DataFrame.from_dict(data, orient='index')
    

    df.to_csv(csv_filename + '.csv', encoding='utf-8', index=False)


json_to_csv('data_movies', 'movies_data')

print("Dữ liệu đã được xuất ra file 'movies_data.csv'")
# Out:
# Dữ liệu đã được xuất ra file 'movies_data.csv'

# %% [markdown]
# Lấy mẫu 30 bộ phim từ data đã có

# %%
import pandas as pd
file_path = "data\\movies_data.csv" 
df = pd.read_csv(file_path, encoding='utf-8', on_bad_lines='skip')
sample = df.sample(30)
sample.to_csv('sample.csv', encoding = 'utf-8', index = False)
